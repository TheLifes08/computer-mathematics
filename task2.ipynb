# %% [markdown]
# # Практическая работа №2: Исследование задач о раскрасках
#
# Выполнил студент гр. 9381 Колованов Родион, вариант 52.

# %% [markdown]
# ## Цель работы
#
# Формирование представления о задачах о раскрасках, выработать умение использование леммы Бёрнсайда для решения задачи о раскрасках, привить навык использования систем компьютерной алгебры для реализации алгоритмов решения задачи.

# %% [markdown]
# ## Основные теоретические положения
#
# #### Определение действия группы на множестве
#
# Пусть $\mathbb{G}$ - группа, $e$ - нейтральный элемент группы $\mathbb{G}$, $\mathbb{X}$ - множество.
#
# $\mathbb{G}$ действует на $\mathbb{X}$, если задана операция $\mathbb{G} \times \mathbb{X} \rightarrow \mathbb{X}$ такая, что $\forall x \in \mathbb{X}$, $g, h \in \mathbb{G}$ выполняется:
# 1. $e x = x$
# 2. $g (h x) = (g h) x$
#
# #### Определение орбиты
#
# Орбитой $x \in \mathbb{X}$ под действием группы $\mathbb{G}$ называется множество $\mathbb{G} x=\{g x | g \in \mathbb{G}\} = Orb(x)$.
#
# Длина орбиты равна $|\mathbb{G} x|$.
#
# #### Определение неподвижной точки
#
# Неподвижными точками элемента $g \in \mathbb{G}$ называются такие $x \in \mathbb{X}$, для которых выполняется: $g x = x$.
#
# Множество неподвижных точек элемента $g \in \mathbb{G}$ обозначается как $\mathbb{X}^g$.
#
# #### Лемма Бернсайда
#
# Количество орбит действия группы $\mathbb{G}$ на $\mathbb{X}$ равно $\frac{1}{|\mathbb{G}|} \sum_{g \in \mathbb{G}}{|\mathbb{X}^g|}$.
#
# #### Определение раскраски
#
# Пусть $I$ - произвольное множество, $\mathbb{C}$ - множество цветов.
#
# Раскраской множества $I$ называется функция $\varphi: I \rightarrow \mathbb{C}$.
#
# $\mathbb{C}^I$ - множество всех раскрасок.
#
# $|\mathbb{C}^I|=|\mathbb{C}|^{|I|}$ - количество всех раскрасок.
#
# #### Определение 5
#
# Пусть $\mathbb{G}$ - группа, действующая на множестве $I$.
#
# Тогда формула $gf(i)=f(g^{-1}i)$, где $g \in \mathbb{G}$, $i \in  I$, $f \in \mathbb{C}^{I}$, задает действие $\mathbb{G}$ на множество $\mathbb{C}^{I}$.
#
# #### Теорема
#
# Для элемента $g \in \mathbb{G}$ и функции $f \in \mathbb{C}^{I}$ эквивалентны следующие условия:
# 1. $gf=f$
# 2. $f(i) = f(g^n i)$, $\forall i \in I$, $\forall n \in \mathbb{Z}$
# 3. Если $i$, $j \in I$ лежат в одном цикле в циклической записи перестановки $\varphi(g)$, то $f(i)=f(j)$.
#
# #### Следствие 1
#
# Количество раскрасок из $\mathbb{C}^{I}$, которые сохраняют данный элемент $g \in \mathbb{G}$, равно $|\mathbb{C}|^{c(\varphi(g))}$, где $c(\varphi)$ - количество независимых циклов в записи перестановки $\varphi$.
#
# #### Лемма 1
#
# Пусть $\tau$ является циклом длины $k$, а $НОД(k, n) = d$.
#
# Тогда перестановка $\tau^n$ является произведением d циклов длины $\frac{k}{d}$.

# %% [markdown]
# ## Постановка задачи
#
# Аналитически решить задачу о раскрасках; графически отобразить решения задачи с использованием системы компьютерной алгебры SageMath. Полученные результаты содержательно проинтерпретировать.
#
# #### Вариант 52
#
# Круг разбит на 70 секторов, каждый из которых покрашен в один из 6 цветов. Сколькими способами можно составить такую мозайку (с точностью до поворота круга)?

# %% [markdown]
# ## Порядок выполнения работы
# 1. Аналитически решить задачу о раскрасках для заданного варианта. Все умозаключения в ходе решения обосновать и содержательно проинтерпретировать.
# 2. Реализовать средствами SageMath функцию, отображающую графически раскраску по заданному номеру. Продемонстрировать работу функции на нескольких примерах. Сделать выводы.
# 3. Дополнительное необязательное задание: для заданного варианта решить задачу в общем виде.

# %% [markdown]
# ## Выполнение работы

# %% [markdown]
# ### Аналитическое решение задачи о раскрасках
#
# Дано множество из 6 цветов $\mathbb{C}$ и множество секторов круга $I = \{x_1, x_2, \ldots, x_{70}\}$, $x_i \in \mathbb{C}$. Необходимо найти количество различных способов раскрасить сектора круга с точностью до поворота круга.
#
# Всего вариантов раскраски секторов круга: $6^{70}$. На множество $\mathbb{C}^I$ всех раскрасок действует группа поворотов $\mathbb{G}$ с операцией композиции. Раскраски, совмещаемые друг с другом каким-нибудь преобразованием из группы $\mathbb{G}$, будут задавать одинаковый круг. При этом раскраски будут задавать одинаковый круг тогда и только тогда, когда они лежат в одной орбите под действием группы $\mathbb{G}$. Таким образом задача сводится к нахождению количества орбит действия группы $\mathbb{G}$ на множество $\mathbb{C}^I$.
#
# Пусть $\tau$ - поворот, переводящий каждое место в следующее (поворот на $\frac{36}{7}$  градусов).
#
# Тогда $\mathbb{S}_I = \{e=\tau^{0}, \tau^{1}, \tau^{2}, \ldots, \tau^{68}, \tau^{69}\}.$
#
# Выпишем все возможные элементы симметрической группы $\mathbb{S}_I$:
#
# $e =\begin{pmatrix}
#       1 & 2 & 3 & \ldots & 70 \\
#       1 & 2 & 3 & \ldots & 70
#     \end{pmatrix} = (1)(2)(3)\ldots(69)(70)$
#
# $\tau = \begin{pmatrix}
#           1 & 2 & 3 & \ldots & 69 & 70 \\
#           2 & 3 & 4 & \ldots & 70 & 1
#         \end{pmatrix} = (1, 2, 3, \ldots, 69, 70)$
#
# $\tau^2 = \tau(\tau) = \begin{pmatrix}
#           1 & 2 & 3 & \ldots & 69 & 70 \\
#           3 & 4 & 5 & \ldots & 1 & 2
#         \end{pmatrix} = (1, 3, 5, \ldots, 67, 69)(2, 4, 6, \ldots, 68, 70)$
#
# $\ldots$
#
# $\tau^{k} = \begin{pmatrix}
#           1 & 2 & 3 & \ldots & 69 & 70 \\
#           (1 + k)mod(70) & (2 + k)mod(70) & (3 + k)mod(70) & \ldots & (69 + k)mod(70) & (70 + k)mod(70)
#         \end{pmatrix}$
#
# $\ldots$
#
# $\tau^{69} = \begin{pmatrix}
#           1 & 2 & 3 & \ldots & 69 & 70 \\
#           70 & 1 & 2 & \ldots & 68 & 69
#         \end{pmatrix} = (70, 69, 68, \ldots, 2, 1)$
#
# $\tau^{70} = e$
#
# Перестановка $\tau$ является циклом длины 70. Пользуясь леммой 1, можно посчитать количество циклов в перестановке $\tau^k \ \forall k \in \{0, 1, 2, 3, \ldots, 69\}$: любая перестановка $\tau^k$ является произведением $d = НОД(70,k)$ независимых циклов.

# %% [markdown]
# Найдем $НОД(70, k)$ для всех $k \in \{0, 1, 2, 3, \ldots, 69\}$:

# %%
gcds = dict()

for k in range(70):
    gcd = GCD(70, k)
    
    if gcd in gcds.keys():
        gcds[gcd].append(k)
    else:
        gcds[gcd] = [k]
        
for pair in gcds.items():
    print("НОД(70, k) = {} для k, принадлежащих {}. Всего элементов: {}.".format(pair[0], pair[1], len(pair[1])))
# Out:
# НОД(70, k) = 70 для k, принадлежащих [0]. Всего элементов: 1.
# НОД(70, k) = 1 для k, принадлежащих [1, 3, 9, 11, 13, 17, 19, 23, 27, 29, 31, 33, 37, 39, 41, 43, 47, 51, 53, 57, 59, 61, 67, 69]. Всего элементов: 24.
# НОД(70, k) = 2 для k, принадлежащих [2, 4, 6, 8, 12, 16, 18, 22, 24, 26, 32, 34, 36, 38, 44, 46, 48, 52, 54, 58, 62, 64, 66, 68]. Всего элементов: 24.
# НОД(70, k) = 5 для k, принадлежащих [5, 15, 25, 45, 55, 65]. Всего элементов: 6.
# НОД(70, k) = 7 для k, принадлежащих [7, 21, 49, 63]. Всего элементов: 4.
# НОД(70, k) = 10 для k, принадлежащих [10, 20, 30, 40, 50, 60]. Всего элементов: 6.
# НОД(70, k) = 14 для k, принадлежащих [14, 28, 42, 56]. Всего элементов: 4.
# НОД(70, k) = 35 для k, принадлежащих [35]. Всего элементов: 1.

# %% [markdown]
# Теперь из следствия 1 можно найти количество раскрасок, которые сохраняет данный элемент $g \in \mathbb{G}$:
#
# $|\mathbb{C}^{e}| = |\mathbb{C}^{c(\tau^0)}| = |\mathbb{C}^{c(e)}| = 6^{70}$ для $g = e$.
#
# $|\mathbb{C}^{\tau^k}| = |\mathbb{C}^{c(\tau^k)}| = 6^{1} = 6$ для $g = \tau^k, k \in \{1, 3, 9, 11, 13, 17, 19, 23, 27, 29, 31, 33, 37, 39, 41, 43, 47, 51, 53, 57, 59, 61, 67, 69\}$. Количество различных $k$: $24$.
#
# $|\mathbb{C}^{\tau^k}| = |\mathbb{C}^{c(\tau^k)}| = 6^{2}$ для $g = \tau^k, k \in \{2, 4, 6, 8, 12, 16, 18, 22, 24, 26, 32, 34, 36, 38, 44, 46, 48, 52, 54, 58, 62, 64, 66, 68\}$. Количество различных $k$: $24$.
#
# $|\mathbb{C}^{\tau^k}| = |\mathbb{C}^{c(\tau^k)}| = 6^{5}$ для $g = \tau^k, k \in \{5, 15, 25, 45, 55, 65\}$. Количество различных $k$: $6$.
#
# $|\mathbb{C}^{\tau^k}| = |\mathbb{C}^{c(\tau^k)}| = 6^{7}$ для $g = \tau^k, k \in \{7, 21, 49, 63\}$. Количество различных $k$: $4$.
#
# $|\mathbb{C}^{\tau^k}| = |\mathbb{C}^{c(\tau^k)}| = 6^{10}$ для $g = \tau^k, k \in \{10, 20, 30, 40, 50, 60\}$. Количество различных $k$: $6$.
#
# $|\mathbb{C}^{\tau^k}| = |\mathbb{C}^{c(\tau^k)}| = 6^{14}$ для $g = \tau^k, k \in \{14, 28, 42, 56\}$. Количество различных $k$: $4$.
#
# $|\mathbb{C}^{\tau^k}| = |\mathbb{C}^{c(\tau^k)}| = 6^{35}$ для $g = \tau^k, k \in \{35\}$
#
# $|\mathbb{G}| = 70$
#
# Теперь воспользуемся леммой Бернсайда:
#
# Количество различных способов раскрасить сектора круга с точностью до поворота круга равно $N = \frac{1}{|\mathbb{G}|} \sum_{g \in \mathbb{G}}{|\mathbb{X}^g|} = \frac{1}{70}(6^{70} + 24 \cdot 6^{1} + 24 \cdot 6^{2} + 6 \cdot 6^{5} + 4 \cdot 6^{7} + 6 \cdot 6^{10} + 4 \cdot 6^{14} + 6^{35}) = 42217205922109732066552966592993231163139317541441800$

# %%
print((6 ** 70 + 24 * 6 + 24 * 6 ** 2 + 6 * 6 ** 5 + 4 * 6 ** 7 + 6 * 6 ** 10 + 4 * 6 ** 14 + 6 ** 35) / 70)
# Out:
# 42217205922109732066552966592993231163139317541441800

# %% [markdown]
# ### Реализация набора классов и функций для графического отображения раскраски по заданному номеру

# %% [markdown]
# Реализуем набор классов для графического отображения раскраски по заданному номеру:

# %%
from random import randint
from enum import Enum

# Перечисление, содержащее цвет (множество цветов)
class Color(Enum):
    RED = (0.95, 0, 0)
    GREEN = (0, 0.7, 0)
    BLUE = (0.2, 0.2, 1)
    YELLOW = (1, 1, 0)
    ORANGE = (1, 0.5, 0)
    PURPLE = (0.6, 0, 0.6)

# Класс сегмента круга  
class Segment:
    def __init__(self, number, color):
        self.number = number
        self.color = color
        
# Класс круга    
class Circle:
    def __init__(self, segments_number, number = None):
        self.segments_number = segments_number
        color_list = list(Color)
        
        if number is None:
            self.segments = [Segment(s + 1, color_list[randint(0, 5)]) for s in range(segments_number)]
        else:
            self.segments = [Segment(s + 1, color_list[int(number[s])]) for s in range(segments_number)]
            
        self.shift = 0
        
    def rotate_right(self, segments_count):
        self.shift += segments_count
        
    def rotate_left(self, segments_count):
        self.shift -= segments_count
        
    def get_segment(self, index):
        return self.segments[(self.shift + index) % self.segments_number]
    
    def set_segment(self, index, value):
        self.segments[(self.shift + index) % self.segments_number] = value
        
    def print_circle(self):
        radius = 10
        thickness = 1
        segments_number = self.segments_number
        steps = 4
        G = Graphics()
        
        for j in range(segments_number):
            L = [[(radius + thickness) * cos(2 * pi * (i + j * steps) / (segments_number * steps)), 
                  (radius + thickness) * sin(2 * pi * (i + j * steps) / (segments_number * steps))] for i in range(steps + 1)]
            L.extend([[radius * cos(2 * pi * (j * steps + steps - i) / (segments_number * steps)), 
                       radius * sin(2 * pi * (j * steps + steps - i) / (segments_number * steps))] for i in range(steps + 1)])
            G += polygon2d(L, axes=False, rgbcolor=self.get_segment(j).color.value, edgecolor="black")
            G += text(str(self.get_segment(j).number), ((radius + thickness / 2) * cos(2 * pi * (1 + j * 2) / (segments_number * 2)), 
                                   (radius + thickness / 2) * sin(2 * pi * (1 + 2 * j) / (segments_number * 2))), rgbcolor="black", fontsize=14)
            G += text(str(j + 1), ((radius - thickness / 2) * cos(2 * pi * (1 + j * 2) / (segments_number * 2)), 
                                   (radius - thickness / 2) * sin(2 * pi * (1 + 2 * j) / (segments_number * 2))), rgbcolor="black", fontsize=14)
            
        G.show(figsize=[16,16])

# %% [markdown]
# Каждому сектору круга соответствует свой индификационный номер и цвет (номер сектора записан внутри сектора). При повороте круга сектор сохраняет свой номер и цвет. Числа внутри круга идентифицируют места и не меняются при повороте.

# %%
def order_number_to_number(order_number, sectors_count):
    if order_number > 6 ** sectors_count:
        order_number = order_number % (6 ** sectors_count)
    
    number = ""

    while order_number > 0:
        number = str(order_number % 6) + number
        order_number //= 6

    if len(number) < sectors_count:
        number = '0' * (sectors_count - len(number)) + number
    
    return number
    
sectors_count = 70
order_number = 25378437234234412356987585852322353523523038249673428
number = order_number_to_number(order_number, sectors_count)
circle = Circle(len(number), number)

print("Круг для номера {}:".format(order_number))
circle.print_circle()
# Out:
# Круг для номера 25378437234234412356987585852322353523523038249673428:
# Graphics object consisting of 210 graphics primitives

# %%
circle.rotate_right(20)
print("Повернем круг на 20 секторов по часовой стрелке: ")
circle.print_circle()
# Out:
# Повернем круг на 20 секторов по часовой стрелке:
# Graphics object consisting of 210 graphics primitives

# %% [markdown]
# ### Решение задачи о раскрасках в общем виде

# %% [markdown]
# Пусть $n$ - количество цветов, и мы по прежнему раскрашиваем круг из 70 секторов. Тогда аналогично рассуждениям из аналитического решения получаем:
#
# Из следствия 1 можно найти количество раскрасок, которые сохраняет данный элемент $g \in \mathbb{G}$:
#
# $|\mathbb{C}^{e}| = |\mathbb{C}^{c(\tau^0)}| = |\mathbb{C}^{c(e)}| = n^{70}$ для $g = e$.
#
# $|\mathbb{C}^{\tau^k}| = |\mathbb{C}^{c(\tau^k)}| = n^{1} = n$ для $g = \tau^k, k \in \{1, 3, 9, 11, 13, 17, 19, 23, 27, 29, 31, 33, 37, 39, 41, 43, 47, 51, 53, 57, 59, 61, 67, 69\}$. Количество различных $k$: $24$.
#
# $|\mathbb{C}^{\tau^k}| = |\mathbb{C}^{c(\tau^k)}| = n^{2}$ для $g = \tau^k, k \in \{2, 4, 6, 8, 12, 16, 18, 22, 24, 26, 32, 34, 36, 38, 44, 46, 48, 52, 54, 58, 62, 64, 66, 68\}$. Количество различных $k$: $24$.
#
# $|\mathbb{C}^{\tau^k}| = |\mathbb{C}^{c(\tau^k)}| = n^{5}$ для $g = \tau^k, k \in \{5, 15, 25, 45, 55, 65\}$. Количество различных $k$: $6$.
#
# $|\mathbb{C}^{\tau^k}| = |\mathbb{C}^{c(\tau^k)}| = n^{7}$ для $g = \tau^k, k \in \{7, 21, 49, 63\}$. Количество различных $k$: $4$.
#
# $|\mathbb{C}^{\tau^k}| = |\mathbb{C}^{c(\tau^k)}| = n^{10}$ для $g = \tau^k, k \in \{10, 20, 30, 40, 50, 60\}$. Количество различных $k$: $6$.
#
# $|\mathbb{C}^{\tau^k}| = |\mathbb{C}^{c(\tau^k)}| = n^{14}$ для $g = \tau^k, k \in \{14, 28, 42, 56\}$. Количество различных $k$: $4$.
#
# $|\mathbb{C}^{\tau^k}| = |\mathbb{C}^{c(\tau^k)}| = n^{35}$ для $g = \tau^k, k \in \{35\}$
#
# $|\mathbb{G}| = 70$
#
# Теперь воспользуемся леммой Бернсайда:
#
# Количество различных способов раскрасить сектора круга с точностью до поворота круга равно $N = \frac{1}{|\mathbb{G}|} \sum_{g \in \mathbb{G}}{|\mathbb{X}^g|} = \frac{1}{70}(n^{70} + 24 \cdot n^{1} + 24 \cdot n^{2} + 6 \cdot n^{5} + 4 \cdot n^{7} + 6 \cdot n^{10} + 4 \cdot n^{14} + n^{35})$

# %% [markdown]
# ## Выводы
#
# В ходе выполнения практической работы были сформированы представления о задачах о раскрасках, выработано умение использования леммы Бёрнсайда для решения задачи о раскрасках, привит навык использования системы компьютерной алгебры SageMath для реализации алгоритмов решения задачи.
#
# По мимо этого был реализован набор классов и функций для графического отображения раскраски по заданному номеру.
